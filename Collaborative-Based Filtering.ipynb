# %% [markdown]
# # Collaborative-Based Filtering

# %%
import pandas
ratings = pandas.read_csv("ratings.csv")
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /root/venv/lib/python3.9/site-packages (1.1.3)
# Requirement already satisfied: scipy>=1.3.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-surprise) (1.9.3)
# Requirement already satisfied: joblib>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-surprise) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-surprise) (1.23.4)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from surprise import Dataset, Reader
reader = Reader(rating_scale=(1, 5))
dataset = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)
dataset

# %% [markdown]
# ## Build the trainset

# %%
trainset = dataset.build_full_trainset()

# %%
list[trainset.all_ratings()]
# Out:
# list[<generator object Trainset.all_ratings at 0x7f6271ddb970>]

# %% [markdown]
# ## Train the Model

# %%
from surprise import SVD
svd = SVD()

# %%
svd.fit(trainset)

# %%
svd.predict(15, 1956).est
# Out:
# 3.4993108604038197

# %% [markdown]
# ## Validation

# %%
from surprise import model_selection
model_selection.cross_validate(svd, dataset, measures=['RMSE', 'MAE'])
# Out:
# {'test_rmse': array([0.90643155, 0.89716965, 0.89263419, 0.90372473, 0.88303429]),
#  'test_mae': array([0.69746275, 0.69045511, 0.68676609, 0.69589114, 0.68086483]),
#  'fit_time': (0.8358607292175293,
#   0.876758337020874,
#   0.8580517768859863,
#   0.8730173110961914,
#   0.8628416061401367),
#  'test_time': (0.10826730728149414,
#   0.09683609008789062,
#   0.11567115783691406,
#   0.09464383125305176,
#   0.24043774604797363)}

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a2885e43-f8fb-49cc-bf1b-00b3263bb6d6' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
